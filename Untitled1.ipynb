# %%
print("Merhaba, VERIYAPILARI ve Algoritmalar _ Python - D2")
# Out:
# Merhaba, VERIYAPILARI ve Algoritmalar _ Python - D2

# %% [markdown]
# Bu hücre, Python'da "Merhaba, VERIYAPILARI ve Algoritmalar _ Python - D2" metnini ekrana yazdırır. `print()` fonksiyonu, parantez içindeki değeri konsola yazmak için kullanılır.

# %%
import sys #import python programlama dilinde kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %% [markdown]
# Bu hücrede:
# - `import sys`: Python'da sistemle ilgili işlevlere erişim sağlayan `sys` modülünü içe aktarır.
# - `print(sys.version)`: Kullanılan Python yorumlayıcısının sürümünü ekrana yazdırır.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Bu hücrede:
# - `from google.colab import drive`: Google Colab ortamında Google Drive'a erişim sağlamak için `drive` modülünü içe aktarır.
# - `drive.mount('/content/drive')`: Google Drive'ınızı `/content/drive` dizinine bağlar, böylece Drive'ınızdaki dosyalara not defterinizden erişebilirsiniz.

# %%
import os
os.chdir('/content/drive/My Drive/GoogleColab')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# /content/drive/My Drive/GoogleColab

# %% [markdown]
# Bu hücrede:
# - `import os`: İşletim sistemi ile etkileşim kurmak için kullanılan `os` modülünü içe aktarır.
# - `os.chdir('/content/drive/My Drive/GoogleColab')`: Çalışma dizinini Google Drive'ınızdaki `My Drive/GoogleColab` klasörüne değiştirir. Bu, not defterinizin o klasördeki dosyalara doğrudan erişmesini sağlar.
# - `!pwd`: Bu bir kabuk komutudur (`!` işareti ile Python kodu dışından çalıştırılır). **p**rint **w**orking **d**irectory'nin kısaltmasıdır ve o anki çalışma dizininizin tam yolunu ekrana yazdırır. Bu, dizin değişikliğinin başarılı olup olmadığını doğrulamak için kullanılır.

# %%
# geçerli bir değişken tanımı

degisken1 = 10

Degisken2 = 20

degisken_3 = 30

_degisken_4 = 40

print(degisken1)
print(Degisken2)
print(degisken_3)
print(_degisken_4)
# Out:
# 10
# 20
# 30
# 40

# %%
# gecersiz değişken tanımlaması

# 1degisken = 50  # Hatalı: Değişken adı sayı ile başlayamaz
# degisken1-4 = 50 # Hatalı: Değişken adı tire işareti içeremez

# Geçerli düzeltmeler aşağıdaki gibi olabilir:

degisken_1 = 50
degisken_bir_dort = 50
# Out:
#   File "/tmp/ipykernel_3931/2424292541.py", line 3
#     1degisken = 50
#     ^
# SyntaxError: invalid decimal literal

# %%
x = 5

y = "Merhaba Dünya"

print(x)

print(y)
# Out:
# 5
# Merhaba Dünya

# %%
print(
  x+3)
# Out:
# 8

# %%
a = 10

print(type(a), a)
# Out:
# <class 'int'> 10

# %%
b = 20.5

print(type(b), b)
# Out:
# <class 'float'> 20.5

# %%
b = 20.5

print(type(b), b)
# Out:
# <class 'float'> 20.5

# %%
# int veri tipinden float'a çevirim işlemi örneği

y = 10

x = float(y)

print(x, type(x))
# Out:
# 10.0 <class 'float'>

# %%
# float veri tipinden int veri tipine çevirim örneği

y = 10.74

x = int(y)

print(x, type(x))
# Out:
# 10 <class 'int'>

# %%
# String - metinsel bilgiyi değişkene atama işlemi

c = "Python Programlama"

print(c, type(c))
# Out:
# Python Programlama <class 'str'>

# %%
# Boolean (True / Doğru - False / Yanlış) Değişken tanımlaması

d = True # 1 - Aktif
e = False # 0 - Pasif

print(d)
print(type(e))
# Out:
# True
# <class 'bool'>

# %%
giris = input ("Bir Sayı Giriniz:")
print(type(giris))
# Out:
# Bir Sayı Giriniz:4545
# <class 'str'>

# %%
import random

rastgele2 = random.randint(1, 20) # randint fonksiyonu bize istediğimiz aralıkta rastgele bir sayı üreten fonksiyondur.

print("Rastgele Gelen Deger: ", rastgele2)
# Out:
# Rastgele Gelen Deger:  13

# %%
import random

rastgele = random.random() # random fonksiyonu bize 0 ile 1 arasında rastgele bir sayı üreten fonksiyondur.

print("Rastgele Gelen Deger: ", rastgele)
# Out:
# Rastgele Gelen Deger:  0.7446381737318886
